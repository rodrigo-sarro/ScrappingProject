# %% [markdown]
# <h1>Project<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Start-opening-the-Chrome-and-the-link" data-toc-modified-id="Start-opening-the-Chrome-and-the-link-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Start opening the Chrome and the link</a></span></li></ul></div>

# %% [markdown]
# ## Libraries

# %%
from dotenv import load_dotenv
from selenium import webdriver
import pandas as pd
import requests
import numpy as np
import os
import time

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## Start opening the Chrome and the link

# %%
def filmes():

    chrome_path = ('C:/Users/rodri/OneDrive/Área de Trabalho/chromedriver')
    driver = webdriver.Chrome(executable_path=chrome_path)
    
    url = ('https://www.netflix.com/br/login?nextpage=https%3A%2F%2Fwww.netflix.com%2Fbrowse')
    driver.get(url)
    
    load_dotenv('login.env')
    login = os.getenv('user')
    password = os.getenv('password')
    
    elem = driver.find_element_by_xpath('//*[@id="id_userLoginId"]')
    elem.send_keys(login)
    time.sleep(1)
    
    elem = driver.find_element_by_xpath('//*[@id="id_password"]')
    elem.send_keys(password)
    
    enter = driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[1]/form/button')
    enter.click()
    time.sleep(2)
    
    perfil = driver.find_element_by_xpath('//*[@id="appMountPoint"]/div/div/div[1]/div[1]/div[2]/div/div/ul/li[2]/div/a/span')
    perfil.click()
    time.sleep(2)
    
    navegar = driver.find_element_by_xpath('//*[@id="appMountPoint"]/div/div/div[1]/div[1]/div[1]/div/div/ul/li[4]/a')
    navegar.click()
    
#def scraping_filme()
   #response = requests.get('https://www.netflix.com/browse/genre/34399')

# %%
filmes()

# %%
chrome_path = ('C:/Users/rodri/OneDrive/Área de Trabalho/chromedriver')
driver = webdriver.Chrome(executable_path=chrome_path)
driver.get('https://www.netflix.com/browse/genre/34399')

html = driver.page_source
driver.close()

# %%
#response = requests.get('https://www.netflix.com/browse/genre/34399')

# %%
#html = response.content

# %%
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <html lang="pt"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="Aob+++752GiUzm1RNSIkM9TINnQDxTlxz02v8hFJK/uGO2hmXnJqH8c/ZpI05b2nLsHDhGO3Ce2zXJUFQmO7jA4AAAB1eyJvcmlnaW4iOiJodHRwczovL25ldGZsaXguY29tOjQ0MyIsImZlYXR1cmUiOiJFbmNyeXB0ZWRNZWRpYUhkY3BQb2xpY3lDaGVjayIsImV4cGlyeSI6MTU0MzI0MzQyNCwiaXNTdWJkb21haW4iOnRydWV9" data-expires="2018-11-26" data-feature="EME Extension - Policy Check" http-equiv="origin-trial"/><meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/><meta content="Assustadores, engraçados, dramáticos, românticos... Nada como um filme para mexer com nossas emoções! Não faltam títulos e experiências esperando por você." name="description"/><title>Filmes | Site Oficial Netflix</title><script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","name":"Filmes","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Movie","name":"Bob Esponja: O Incrível Resgate","url":"https://www.netflix.com/br/title/81312563"}},{"@type":"ListItem","position":2,"item":{"@type":"Movie","name":"Luccas Neto em: O Mapa do Tesouro","url":"https://www.netflix.com/br/title/81295543"}},{"@type":"ListItem","position":3,"item":{"@type":"Movie","name":"Amor com Data Marcada","url":"https://www.netflix.com/br/title/81034553"}},{"@type":"ListItem","position":4,"item":{"@type":"Movie","name":"Missão Presente de Natal","url":"https://www.netflix.com/br/title/81026186"}},{"@type":"ListItem","position":5,"item":{"@type":"Movie","name":"A Barraca do Beijo 2","url":"https://www.netflix.com/br/title/81026818"}},{"@type":"ListItem","position":6,"item":{"@type":"Movie","name":"Natal Sob Medida","url":"https://www.netflix.com/br/title/81088157"}},{"@type":"ListItem","position":7,"item":{"@type":"Movie","name":"O Halloween do Hubie","url":"https://www.netflix.com/br/title/80245104"}},{"@type":"ListItem","position":8,"item":{"@type":"Movie","name":"Troco em Dobro","url":"https://www.netflix.com/br/title/81005492"}},{"@type":"ListItem","position":9,"item":{"@type":"Movie","name":"Hotel Transilvânia 2","url":"https://www.netflix.com/br/title/80048061"}},{"@type":"ListItem","position":10,"item":{"@type":"Movie","name":"Crônicas de Natal","url":"https://www.netflix.com/br/title/80199682"}},{"@type":"ListItem","position":11,"item":{"@type":"Movie","name":"Nanny McPhee - A babá encantada","url":"https://www.netflix.com/br/title/70040681"}},{"@type":"ListItem","position":12,"item":{"@type":"Movie","name":"Scooby-Doo","url":"https://www.netflix.com/br/title/60020823"}},{"@type":"ListItem","position":13,"item":{"@type":"Movie","name":"Scooby-Doo 2: Monstros à Solta","url":"https://www.netflix.com/br/title/60033341"}},{"@type":"ListItem","position":14,"item":{"@type":"Movie","name":"Meu Malvado Favorito 2","url":"https://www.netflix.com/br/title/70264803"}},{"@type":"ListItem","position":15,"item":{"@type":"Movie","name":"Tá Chovendo Hambúrguer","url":"https://www.netflix.com/br/title/70113007"}},{"@type":"ListItem","position":16,"item":{"@type":"Movie","name":"Modo Avião","url":"https://www.netflix.com/br/title/81056195"}},{"@type":"ListItem","position":17,"item":{"@type":"Movie","name":"Bob Esponja - Um Herói Fora D'Água","url":"https://www.netflix.com/br/title/80011621"}},{"@type":"ListItem","position":18,"item":{"@type":"Movie","name":"A Barraca do Beijo","url":"https://www.netflix.com/br/title/80143556"}},{"@type":"ListItem","position":19,"item":{"@type":"Movie","name":"Emoji: O Filme","url":"https://www.netflix.com/br/title/80121840"}},{"@type":"ListItem","position":20,"item":{"@type":"Movie","name":"A Fantástica Fábrica de Chocolate","url":"https://www.netflix.com/br/title/70021648"}},{"@type":"ListItem","position":21,"item":{"@type":"Movie","name":"Um Natal de Descobertas","url":"https://www.netflix.com/br/title/81240442"}},{"@type":"ListItem","position":22, ...
#
# </script></head><body><div id="appMountPoint"><div class="basicLayout browseTitlesGallery dark" dir="ltr" lang="pt-BR"><div class="nm-collections-page"><div class="nm-content-header is-fixed" data-uia="site-header"><div class="nm-content-header-section nm-content-header-left"><a class="svg-nfLogo" data-uia="netflix-header-svg-logo" href="/"><svg class="svg-icon svg-icon-n-logo" focusable="true" viewbox="225 0 552 1000"><defs><radialgradient gradienttransform="matrix(.38 0 .5785 1 .02 0)" id="4c34344d-209c-401b-804b-50e5e8a80ad1-a" r="75%"><stop offset="60%" stop-opacity=".3"></stop><stop offset="90%" stop-opacity=".05"></stop><stop offset="100%" stop-opacity="0"></stop></radialgradient></defs><path d="M225 0v1000c60-8 138-14 198-17V0H225" fill="#b1060e"></path><path d="M579 0v983c71 3 131 9 198 17V0H579" fill="#b1060e"></path><path d="M225 0v200l198 600V557l151 426c76 3 136 9 203 17V800L579 200v240L423 0H225" fill="url(#4c34344d-209c-401b-804b-50e5e8a80ad1-a)"></path><path d="M225 0l349 983c76 3 136 9 203 17L423 0H225" fill="#e50914"></path></svg><span class="screen-reader-text">Netflix</span></a><a class="svg-nfLogo" data-uia="netflix-header-svg-logo" href="/"><svg class="svg-icon svg-icon-netflix-logo" focusable="true" viewbox="0 0 111 30"><g id="netflix-logo"><path d="M105.06233,14.2806261 L110.999156,30 C109.249227,29.7497422 107.500234,29.4366857 105.718437,29.1554972 L102.374168,20.4686475 L98.9371075,28.4375293 C97.2499766,28.1563408 95.5928391,28.061674 93.9057081,27.8432843 L99.9372012,14.0931671 L94.4680851,-5.68434189e-14 L99.5313525,-5.68434189e-14 L102.593495,7.87421502 L105.874965,-5.68434189e-14 L110.999156,-5.68434189e-14 L105.06233,14.2806261 Z M90.4686475,-5.68434189e-14 L85.8749649,-5.68434189e-14 L85.8749649,27.2499766 C87.3746368,27.3437061 88.9371075,27.4055675 90.4686475,27.5930265 L90.4686475,-5.68434189e-14 Z M81.9055207,26.93692 C77.7186241,26.6557316 73.5307901,26.4064111 69.250164,26.3117443 L69.250164,-5.68434189e-14 L73.9366389,-5.68434189e-14 L73.9366389,21.8745899 C76.6248008,21.9373887 79.3120255,22.1557784 81.9055207,22.2804387 L81.9055207,26.93692 Z M64.2496954,10.6561065 L64.2496954,15.3435186 L57.8442216,15.3435186 L57.8442216,25.9996251 L53.2186709,25.9996251 L53.2186709,-5.68434189e-14 L66.3436123,-5.68434189e-14 L66.3436123,4.68741213 L57.8442216,4.68741213 L57.8442216,10.6561065 L64.2496954,10.6561065 Z M45.3435186,4.68741213 L45.3435186,26.2498828 C43.7810479,26.2498828 42.1876465,26.2498828 40.6561065,26.3117443 L40.6561065,4.68741213 L35.8121661,4.68741213 L35.8121661,-5.68434189e-14 L50.2183897,-5.68434189e-14 L50.2183897,4.68741213 L45.3435186,4.68741213 Z M30.749836,15.5928391 C28.687787,15.5928391 26.2498828,15.5928391 24.4999531,15.6875059 L24.4999531,22.6562939 C27.2499766,22.4678976 30,22.2495079 32.7809542,22.1557784 L32.7809542,26.6557316 L19.812541,27.6876933 L19.812541,-5.68434189e-14 L32.7809542,-5.68434189e-14 L32.7809542,4.68741213 L24.4999531,4.68741213 L24.4999531,10.9991564 C26.3126816,10.9991564 29.0936358,10.9054269 30.749836,10.9054269 L30.749836,15.5928391 Z M4.78114163,12.9684132 L4.78114163,29.3429562 C3.09401069,29.5313525 1.59340144,29.7497422 0,30 L0,-5.68434189e-14 L4.4690224,-5.68434189e-14 L10.562377,17.0315868 L10.562377,-5.68434189e-14 L15.2497891,-5.68434189e-14 L15.2497891,28.061674 C13.5935889,28.3437998 11.906458,28.4375293 10.1246602,28.6868498 L4.78114163,12.9684132 Z" id="Fill-14"></path></g></svg><span class="screen-reader-text">Netflix</span></a></div><div class="nm-content-header-section nm-content-header-right"><div class="nm-content-header-text">SÉRIES E FILMES ILIMITADOS</div><button autocomplete="off" class="btn btn-get-started btn-red btn-large" data-uia="homepage-link-button" role="link" tabindex="0" type="submit">ASSINE A NETFLIX</button><a class="authLinks" data-uia="header-login-link" href="/login?nextpage=https%3A%2F%2Fwww.netflix.com%2Fbrowse%2Fgenre%2F34399">Entrar</a></div></div><div class="nm-collections-container" data-uia="coll ...
# if ('serviceWorker' in navigator && navigator.serviceWorker.getRegistrations) {
#     navigator.serviceWorker.getRegistrations().then(function(registrations) {
#         if (registrations) {
#             registrations.forEach(function (registration) {
#                 registration.unregister().catch(function () {});
#             });
#         }
#     }).catch(function () {});
# }
# </script></body></html>

# %%
nomes = soup.find_all('span', attrs = {'class','nm-collections-title-name'})

# %%
movie = [filme.text.strip() for filme in soup.find_all('span', attrs = {'class','nm-collections-title-name'})]

# %%
movie
# Out:
# ['Bob Esponja: O Incrível Resgate',
#  'Luccas Neto em: O Mapa do Tesouro',
#  'Amor com Data Marcada',
#  'Missão Presente de Natal',
#  'A Barraca do Beijo 2',
#  'Natal Sob Medida',
#  'O Halloween do Hubie',
#  'Troco em Dobro',
#  'Hotel Transilvânia 2',
#  'Crônicas de Natal',
#  'Nanny McPhee - A babá encantada',
#  'Scooby-Doo',
#  'Scooby-Doo 2: Monstros à Solta',
#  'Meu Malvado Favorito 2',
#  'Tá Chovendo Hambúrguer',
#  'Modo Avião',
#  "Bob Esponja - Um Herói Fora D'Água",
#  'A Barraca do Beijo',
#  'Emoji: O Filme',
#  'A Fantástica Fábrica de Chocolate',
#  'Um Natal de Descobertas',
#  'Alvin e os Esquilos: Na Estrada',
#  'Feel the Beat',
#  'Norbit',
#  'Matilda',
#  'Pets Unidos!',
#  'As férias de Mr. Bean',
#  'Mistério no Mediterrâneo',
#  'Hitch – Conselheiro Amoroso',
#  'A Casa Caiu: Um Cassino na Vizinhança',
#  'Tá Chovendo Hambúrguer 2',
#  'O Natal de Cinderela',
#  'O Grinch',
#  'Crush à Altura',
#  'Luccas Neto em: Acampamento de Férias 2',
#  'Luccas Neto em: O Hotel Mágico',
#  'Para todos os garotos: P.S. ainda amo você',
#  'Gente grande',
#  'O Segredo dos Animais',
#  'Luccas Neto em: Uma Babá Muito Esquisita',
#  'Teste de Paternidade',
#  'Dançarina Imperfeita',
#  'Amor Garantido',
#  'The Late Bloomer',
#  'O Pequenino',
#  'Meu Malvado Favorito',
#  'O Chefinho – Pega Esse Bebê!',
#  'A Bailarina',
#  'Para Todos os Garotos que Já Amei',
#  'Lista de Desejos de Natal',
#  'Hotel Transilvânia',
#  'Os Smurfs 2',
#  'Shrek para Sempre – O Capítulo Final',
#  'Amor em Obras',
#  'Klaus',
#  'Madagascar 3: Os procurados',
#  'Luccas Neto em: Acampamento de Férias',
#  'Carrossel, O Filme',
#  'A Babá: Rainha da Morte',
#  'Gente Grande 2',
#  'Até Que A Sorte Nos Separe 3',
#  'Madagascar 2',
#  'O Amor Não Tira Férias',
#  'Seis Vezes Confusão',
#  'O Máskara',
#  'Em Ritmo de Fuga',
#  'Luccas Neto em: Dia das Crianças',
#  'O Date Perfeito',
#  'Férias Frustradas',
#  'Rango',
#  'Meninas Malvadas',
#  'Um Passado de Presente',
#  'A Hora do Rush 2',
#  'Questão de Tempo',
#  'Meus 15 Anos',
#  'Jurassic World: Reino Ameaçado',
#  'Tropa de Elite',
#  'Matrix',
#  'Resgate',
#  'Os Sete Magníficos',
#  'Lanterna Verde',
#  'The Old Guard',
#  'Power',
#  'Velozes e Furiosos 7',
#  'Esquadrão 6',
#  'Homem-Aranha: De Volta ao Lar',
#  'Troco em Dobro',
#  'Esquadrão Suicida',
#  'Matrix Reloaded',
#  'Rota de Fuga',
#  'Era uma vez no Oeste',
#  'Velozes & furiosos 5 - Operação Rio',
#  'Matrix Revolutions',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Rocky: Um Lutador',
#  'Mulher-Maravilha',
#  'O cavaleiro das trevas',
#  'O Procurado',
#  'Parker',
#  'S.W.A.T. – Comando Especial',
#  'Velozes & Furiosos 6',
#  'O Cobrador de Dívidas 2',
#  'Velozes e Furiosos',
#  'O Último Caçador de Bruxas',
#  'Vingança',
#  'Terremoto: A Falha de San Andreas',
#  'Bala Perdida',
#  'Atirador',
#  'Kong: A Ilha da Caveira',
#  'Viagem ao Centro da Terra',
#  'Velozes e Furiosos 3 – Desafio em Tóquio',
#  'Operação Fronteira',
#  'Colombiana - em busca de vingança',
#  'Fim do Mundo',
#  'Transformers',
#  'Guerra Mundial Z',
#  'S.W.A.T. - Operação Escorpião',
#  'Constantine',
#  'The Seven Deadly Sins - Prisioneiros do Céu',
#  'Solomon Kane - O Caçador de Demônios',
#  'Onde Está Segunda?',
#  'Motoqueiro fantasma',
#  'Deuses do Egito',
#  'O Protetor',
#  'Polar',
#  'Círculo de Fogo: A Revolta',
#  'A Hora do Rush 2',
#  'Batman vs Superman: A Origem da Justiça',
#  '+ Velozes + Furiosos',
#  'Operações Especiais',
#  'Vingança Fatal',
#  'Shaft',
#  'O Espetacular Homem-Aranha',
#  'Do Fundo do Mar',
#  'O Senhor dos Anéis – A Sociedade do Anel',
#  'Velozes e Furiosos 4',
#  'Uma saída de mestre',
#  'Bright',
#  'Dose Dupla',
#  'O Regresso',
#  'Os indomáveis',
#  'O Último Mestre do Ar',
#  'Transformers - A Era da Extinção',
#  'O Cobrador de Dívidas',
#  'Homem-aranha 3',
#  'Próxima Parada: Apocalipse',
#  'Os Mercenários 2',
#  'Anjos da Noite – O Despertar',
#  'A Caverna',
#  'Lucy',
#  '365 dni',
#  'Bronx',
#  'Quando a Vida Acontece',
#  'Creed II',
#  'Enola Holmes',
#  'O Limite da Traição',
#  'A Lição de Moremi',
#  'Cinquenta Tons de Liberdade',
#  'Quarto de Guerra',
#  'Milagre na Cela 7',
#  'Rebecca - A Mulher Inesquecível',
#  'A Princesa e a Plebeia',
#  'A Menina e o Leão',
#  'Sniper Americano',
#  'Creed: Nascido para Lutar',
#  'Lancelot, o Primeiro Cavaleiro',
#  'Rocky: Um Lutador',
#  'Rosa e Momo',
#  'Feel the Beat',
#  'Roman J. Israel',
#  'Por Lugares Incríveis',
#  'À prova de fogo',
#  'Mogli - Entre Dois Mundos',
#  'Bird Box',
#  'O Menino que Descobriu o Vento',
#  'De volta à lagoa azul',
#  'O Príncipe do Natal',
#  'A Escolha',
#  'Orgulho e Preconceito',
#  'Todo Dia',
#  'Carrossel, O Filme',
#  'Bala Perdida',
#  'O Impossível',
#  'O Feitiço do Natal',
#  'No Coração do Mar',
#  'O Diabo de Cada Dia',
#  'O Príncipe do Natal: O Bebê Real',
#  'O Resgate do Soldado Ryan',
#  'Os Dez Mandamentos - O Filme',
#  'Mãos talentosas: A história de Ben Carson',
#  'Dunkirk',
#  'Rocky IV',
#  'Rocky III - O Desafio Supremo',
#  'Fique rico ou morra tentando',
#  'O Príncipe do Natal: O Casamento Real',
#  'Cartão de Natal',
#  'Um olhar do paraíso',
#  'Lion - Uma jornada para casa',
#  'Milagres do Paraíso',
#  'Questão de Tempo',
#  'Meus 15 Anos',
#  'A Menina e o Porquinho',
#  'Top Gun - Ases Indomáveis',
#  'À Espera de um milagre',
#  'A Vida Secreta de Zoe',
#  'Rocky V',
#  'O Jovem Messias',
#  'Os donos da rua',
#  'Fome de Poder',
#  'Remédio Amargo',
#  'Como Estrelas na Terra',
#  'Golpe Duplo',
#  'O Regresso',
#  'V de vingança',
#  'Diário de uma paixão',
#  'Resgate do Coração',
#  'Django Livre',
#  'Homens de Coragem',
#  'Invencível',
#  'Rocky Balboa',
#  'Carrossel 2 – O Sumiço de Maria Joaquina',
#  'Estrada Sem Lei',
#  'Rocky II - A Revanche',
#  'Miss India',
#  'Os 7 de Chicago',
#  'Sniper Americano',
#  'Roman J. Israel',
#  'O Menino que Descobriu o Vento',
#  'O Impossível',
#  'No Coração do Mar',
#  'Invocação do Mal 2',
#  'Mãos talentosas: A história de Ben Carson',
#  'Dunkirk',
#  'Lion - Uma jornada para casa',
#  'Milagres do Paraíso',
#  'Fome de Poder',
#  'O Regresso',
#  'Homens de Coragem',
#  'Invencível',
#  'Estrada Sem Lei',
#  'Os 7 de Chicago',
#  'Dois Papas',
#  'Aliança do Crime',
#  'O Gângster',
#  'À Procura da Felicidade',
#  'Coach Carter — Treino para a vida',
#  'Escritores da Liberdade',
#  'Mais Forte que o Mundo - A História de José Aldo',
#  'Fuga de Alcatraz',
#  'Sem dor, sem ganho',
#  'Sully: O Herói do Rio Hudson',
#  '22 de Julho',
#  'O Aviador',
#  'Patch Adams, o Amor é Contagioso',
#  'Andar Montar Rodeio - A Virada de Amberley',
#  'O Rei',
#  'Um Reino Unido',
#  '100 Metros',
#  'Operação Final',
#  'Honra ao Mérito',
#  'Elizabeth  [1998]',
#  'A Colheita da Fé',
#  '6 Dias',
#  'A Teoria de Tudo',
#  'O Homem que Mudou o Jogo',
#  'A Caminho da Fé',
#  'La Bamba',
#  'Legítimo Rei',
#  'Kiss & Cry',
#  'Nada a Perder – Parte 1',
#  'Jadotville',
#  'Kardec',
#  'Horizonte Profundo: Desastre no Golfo',
#  'Elisa y Marcela',
#  'Um Homem Entre Gigantes',
#  'Inimigos públicos',
#  'Ted Bundy: A Irresistível Face do Mal',
#  'The Dirt – Confissões do Mötley Crüe',
#  'A Grande Aposta',
#  'Castelo de Areia',
#  'Um estado de liberdade',
#  'Altos Negócios',
#  'O Fotógrafo de Mauthausen',
#  'O Homem das Mil Caras',
#  'A Escalada',
#  'Getúlio',
#  'O Destino de uma Nação',
#  'Crazy Trips - Budapeste',
#  'Meu Nome é Dolemite',
#  'A lista de Schindler',
#  'The Post - A Guerra Secreta',
#  'Escobar: A Traição',
#  'Elizabeth: A Era de Ouro',
#  'Ana e Vitória',
#  'Lost Girls - Os Crimes de Long Island',
#  'Homem-Absorvente',
#  'King Cobra',
#  'First They Killed My Father',
#  'Os Últimos das Filipinas',
#  'Amarga Sinfonia de Auschwitz',
#  'The Old Guard',
#  'Power',
#  'Velozes e Furiosos 7',
#  'Esquadrão 6',
#  'Homem-Aranha: De Volta ao Lar',
#  'Troco em Dobro',
#  'Esquadrão Suicida',
#  'Matrix Reloaded',
#  'Scooby-Doo',
#  'Rota de Fuga',
#  'Era uma vez no Oeste',
#  'A Menina e o Leão',
#  'Velozes & furiosos 5 - Operação Rio',
#  'Matrix Revolutions',
#  'Sniper Americano',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Rocky: Um Lutador',
#  'Mulher-Maravilha',
#  'O cavaleiro das trevas',
#  'O Procurado',
#  'Parker',
#  'Mogli - Entre Dois Mundos',
#  'S.W.A.T. – Comando Especial',
#  'Velozes & Furiosos 6',
#  'O Cobrador de Dívidas 2',
#  'Velozes e Furiosos',
#  'Anjos da Noite: A Rebelião',
#  'De volta à lagoa azul',
#  'O Último Caçador de Bruxas',
#  'Vingança',
#  'Terremoto: A Falha de San Andreas',
#  'Bala Perdida',
#  'Atirador',
#  'Kong: A Ilha da Caveira',
#  'Viagem ao Centro da Terra',
#  'No Coração do Mar',
#  'Velozes e Furiosos 3 – Desafio em Tóquio',
#  'Operação Fronteira',
#  'Colombiana - em busca de vingança',
#  'Fim do Mundo',
#  'O Máskara',
#  'Transformers',
#  'O Resgate do Soldado Ryan',
#  'Guerra Mundial Z',
#  'S.W.A.T. - Operação Escorpião',
#  'Constantine',
#  'Em Ritmo de Fuga',
#  'The Seven Deadly Sins - Prisioneiros do Céu',
#  'Solomon Kane - O Caçador de Demônios',
#  'Onde Está Segunda?',
#  'Motoqueiro fantasma',
#  'Deuses do Egito',
#  'O Protetor',
#  'Polar',
#  'Círculo de Fogo: A Revolta',
#  'A Hora do Rush 2',
#  'Batman vs Superman: A Origem da Justiça',
#  '+ Velozes + Furiosos',
#  'Operações Especiais',
#  'Vingança Fatal',
#  'Top Gun - Ases Indomáveis',
#  'Shaft',
#  'O Espetacular Homem-Aranha',
#  'Do Fundo do Mar',
#  'O Senhor dos Anéis – A Sociedade do Anel',
#  'Velozes e Furiosos 4',
#  'Uma saída de mestre',
#  'Bright',
#  'Dose Dupla',
#  'O Regresso',
#  'V de vingança',
#  'Os indomáveis',
#  'O Último Mestre do Ar',
#  'Transformers - A Era da Extinção',
#  'Goosebumps: Monstros e Arrepios',
#  'A Caminho da Lua',
#  'Uma Invenção de Natal',
#  'A Lição de Moremi',
#  'O Halloween do Hubie',
#  'Milagre na Cela 7',
#  'Rebecca - A Mulher Inesquecível',
#  'A Menina e o Leão',
#  'Modo Avião',
#  'O Dilema das Redes',
#  'Rosa e Momo',
#  '#Alive',
#  'Feel the Beat',
#  'Pets Unidos!',
#  'BLACKPINK: Light Up the Sky',
#  'Mistério no Mediterrâneo',
#  'Por Lugares Incríveis',
#  'O Natal de Cinderela',
#  'Crush à Altura',
#  'Luccas Neto em: Acampamento de Férias 2',
#  'Luccas Neto em: O Hotel Mágico',
#  'O Cobrador de Dívidas 2',
#  'O Menino que Descobriu o Vento',
#  'Para todos os garotos: P.S. ainda amo você',
#  'Teste de Paternidade',
#  'Dançarina Imperfeita',
#  'Amor Garantido',
#  'O Chefinho – Pega Esse Bebê!',
#  'Amor em Obras',
#  'Klaus',
#  'Luccas Neto em: Acampamento de Férias',
#  'Bala Perdida',
#  'Manual de Caça a Monstros',
#  'A Babá: Rainha da Morte',
#  'Operação Fronteira',
#  'O Que Ficou Para Trás',
#  'O Diabo de Cada Dia',
#  'Fim do Mundo',
#  'O Príncipe do Natal: O Bebê Real',
#  'Seis Vezes Confusão',
#  'Luccas Neto em: Dia das Crianças',
#  'Cenas de um Homicídio: Uma Família Vizinha',
#  'O Date Perfeito',
#  'Os Segredos de Saqqara',
#  'Um Passado de Presente',
#  'Shaft',
#  'The Silence',
#  'Pokémon: Mewtwo Contra-ataca — Evolução',
#  'Os Irmãos Willoughby',
#  'Remédio Amargo',
#  'Luccas Neto em: O Fim do Natal',
#  'Resgate do Coração',
#  'Estrada Sem Lei',
#  'Miss India',
#  'Os 7 de Chicago',
#  'Campo do Medo',
#  'Mundo Bita - Bita e o Nosso Mundo',
#  'O Natal Está no Ar',
#  'O Irlandês',
#  'Dois Papas',
#  'Cinderela Pop',
#  'Olhos de Gato',
#  'Kadaver',
#  'Por Uma Vida Melhor',
#  'A Tenente de Cargil',
#  'O Começo da Vida 2: Lá Fora',
#  'A Missy Errada',
#  'Fratura',
#  'Eli',
#  'Ricos de Amor',
#  'É o Bicho!',
#  'Encontro Fatal',
#  'Obsessão Secreta',
#  'Amiga do Inimigo',
#  'The Last Days of American Crime',
#  'Procura-se um pai',
#  'Cinquenta Tons de Liberdade',
#  'O Natal de Heidi',
#  'A Princesa e a Plebeia',
#  'Modo Avião',
#  'Lancelot, o Primeiro Cavaleiro',
#  'A Barraca do Beijo',
#  'Um Natal de Descobertas',
#  'Norbit',
#  'Por Lugares Incríveis',
#  'À prova de fogo',
#  'Hitch – Conselheiro Amoroso',
#  'O Natal de Cinderela',
#  'Crush à Altura',
#  'Para todos os garotos: P.S. ainda amo você',
#  'Teste de Paternidade',
#  'De volta à lagoa azul',
#  'Amor Garantido',
#  'O Príncipe do Natal',
#  'A Escolha',
#  'Uma Pousada de Presente',
#  'Your Name',
#  'Para Todos os Garotos que Já Amei',
#  'Lista de Desejos de Natal',
#  'Amor em Obras',
#  'Orgulho e Preconceito',
#  'Todo Dia',
#  'O Feitiço do Natal',
#  'O Amor Não Tira Férias',
#  'O Príncipe do Natal: O Bebê Real',
#  'O Date Perfeito',
#  'Um Passado de Presente',
#  'O Príncipe do Natal: O Casamento Real',
#  'Cartão de Natal',
#  'Questão de Tempo',
#  'Top Gun - Ases Indomáveis',
#  'Um Lugar Chamado Notting Hill',
#  'Como Ser Solteira',
#  'Diário de uma paixão',
#  'Resgate do Coração',
#  'Amizade Colorida',
#  'A Wish for Christmas',
#  'Ponto de decisão',
#  'Jack: O Caçador de Gigantes',
#  'Olhos de Gato',
#  'Forrest Gump',
#  'A Morte e Vida de Charlie',
#  'Sem Prada Nem Nada',
#  'Paisagem de Natal',
#  'A Missy Errada',
#  'A casa das coelhinhas',
#  'Ricos de Amor',
#  'Ghost: Do Outro Lado da Vida',
#  'Sexo sem Compromisso',
#  'O Professor Aloprado',
#  'Casa comigo?',
#  'Cinco Anos de Noivado',
#  'Era uma vez um Casamento',
#  'D.U.F.F.',
#  'MILF',
#  'Tudo e Todas as Coisas',
#  'Felicidade por um Fio',
#  'Pense como eles',
#  'Homem ao Mar',
#  'Meu Passado Me Condena 2: O Filme',
#  'Meu Passado Me Condena',
#  'Pecados íntimos',
#  'Um príncipe em Nova York',
#  'Nu',
#  'Além da Realidade',
#  'Megarrromântico',
#  'Amor.com',
#  'Em algum lugar do passado',
#  'Sadece Sen',
#  'Newness',
#  'Amor à Segunda Vista',
#  'It: A Coisa',
#  'As aventuras de Sharkboy e Lavagirl',
#  'Hotel Transilvânia 2',
#  'Crônicas de Natal',
#  'Matrix Reloaded',
#  'Scooby-Doo',
#  'Rota de Fuga',
#  'Scooby-Doo 2: Monstros à Solta',
#  'Meu Malvado Favorito 2',
#  'Rebecca - A Mulher Inesquecível',
#  'Tá Chovendo Hambúrguer',
#  "Bob Esponja - Um Herói Fora D'Água",
#  'Velozes & furiosos 5 - Operação Rio',
#  'Matrix Revolutions',
#  'Sniper Americano',
#  'Creed: Nascido para Lutar',
#  'Lancelot, o Primeiro Cavaleiro',
#  'Emoji: O Filme',
#  'A Fantástica Fábrica de Chocolate',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Mulher-Maravilha',
#  'O cavaleiro das trevas',
#  'Alvin e os Esquilos: Na Estrada',
#  'Norbit',
#  'Matilda',
#  'O Procurado',
#  'Mistério no Mediterrâneo',
#  'Parker',
#  'A noiva-cadáver',
#  'Hitch – Conselheiro Amoroso',
#  'A Casa Caiu: Um Cassino na Vizinhança',
#  'Tá Chovendo Hambúrguer 2',
#  'O Grinch',
#  'Bird Box',
#  'S.W.A.T. – Comando Especial',
#  'Velozes & Furiosos 6',
#  'Velozes e Furiosos',
#  'Para todos os garotos: P.S. ainda amo você',
#  'Gente grande',
#  'Anjos da Noite: A Rebelião',
#  'O Segredo dos Animais',
#  'O Pequenino',
#  'Meu Malvado Favorito',
#  'O Último Caçador de Bruxas',
#  'Hotel Transilvânia',
#  'Os Smurfs 2',
#  'Shrek para Sempre – O Capítulo Final',
#  'Terremoto: A Falha de San Andreas',
#  'Klaus',
#  'A Casa de Cera',
#  'Madagascar 3: Os procurados',
#  'Atirador',
#  'Manual de Caça a Monstros',
#  'O Impossível',
#  'Kong: A Ilha da Caveira',
#  'Viagem ao Centro da Terra',
#  'Gente Grande 2',
#  'No Coração do Mar',
#  'Velozes e Furiosos 3 – Desafio em Tóquio',
#  'O Expresso Polar',
#  'Operação Fronteira',
#  'Madagascar 2',
#  'O Amor Não Tira Férias',
#  'Seis Vezes Confusão',
#  'Invocação do Mal 2',
#  'O Máskara',
#  'Transformers',
#  'O Resgate do Soldado Ryan',
#  'Guerra Mundial Z',
#  'Constantine',
#  'Poltergeist: O Fenômeno',
#  'Rocky IV',
#  'Motoqueiro fantasma',
#  'Rocky III - O Desafio Supremo',
#  'Fique rico ou morra tentando',
#  'Esquadrão Suicida',
#  'Rota de Fuga',
#  "Bob Esponja - Um Herói Fora D'Água",
#  'Velozes & furiosos 5 - Operação Rio',
#  'Matrix Revolutions',
#  'Creed: Nascido para Lutar',
#  'Emoji: O Filme',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Mulher-Maravilha',
#  'O cavaleiro das trevas',
#  'Pets Unidos!',
#  'BLACKPINK: Light Up the Sky',
#  'Mistério no Mediterrâneo',
#  'Parker',
#  'S.W.A.T. – Comando Especial',
#  'Velozes & Furiosos 6',
#  'O Cobrador de Dívidas 2',
#  'Velozes e Furiosos',
#  'O Último Caçador de Bruxas',
#  'O Chefinho – Pega Esse Bebê!',
#  'Terremoto: A Falha de San Andreas',
#  'Madagascar 3: Os procurados',
#  'Bala Perdida',
#  'Manual de Caça a Monstros',
#  'Kong: A Ilha da Caveira',
#  'No Coração do Mar',
#  'Velozes e Furiosos 3 – Desafio em Tóquio',
#  'Operação Fronteira',
#  'Fim do Mundo',
#  'Transformers',
#  'Os Dez Mandamentos - O Filme',
#  'S.W.A.T. - Operação Escorpião',
#  'Em Ritmo de Fuga',
#  'The Seven Deadly Sins - Prisioneiros do Céu',
#  'Solomon Kane - O Caçador de Demônios',
#  'Onde Está Segunda?',
#  'Rocky IV',
#  'Deuses do Egito',
#  'Círculo de Fogo: A Revolta',
#  'A Hora do Rush 2',
#  'A Origem dos Guardiões',
#  'Batman vs Superman: A Origem da Justiça',
#  'Operações Especiais',
#  'Vingança Fatal',
#  'Top Gun - Ases Indomáveis',
#  'Shaft',
#  'Os Smurfs e a Vila Perdida',
#  'O Espetacular Homem-Aranha',
#  'Velozes e Furiosos 4',
#  'Pokémon: Mewtwo Contra-ataca — Evolução',
#  'Uma saída de mestre',
#  'Bright',
#  'Golpe Duplo',
#  'Kung Fu Panda',
#  'Dose Dupla',
#  'Homens de Coragem',
#  'O Último Mestre do Ar',
#  'Transformers - A Era da Extinção',
#  'Goosebumps: Monstros e Arrepios',
#  'Invencível',
#  'Rocky Balboa',
#  'O Cobrador de Dívidas',
#  'Homem-aranha 3',
#  'Jogos Vorazes: A Esperança - O Final',
#  'Os Mercenários 2',
#  'Animais Fantásticos e Onde Habitam',
#  'Lucy',
#  'Jogos Vorazes: Em Chamas',
#  'Anaconda 2 - A Caçada pela Orquídea Sangrenta',
#  'Quebrando regras 2',
#  'O Agente da U.N.C.L.E.',
#  'O Terno de Dois Bilhões de Dólares',
#  'Gladiador',
#  'A Tenente de Cargil',
#  'Kung Fu Panda 2',
#  '#Alive',
#  'Bird Box',
#  'O Poço',
#  'Pânico em Alto Mar',
#  'O Diabo de Cada Dia',
#  'A Vida Secreta de Zoe',
#  'The Silence',
#  'Remédio Amargo',
#  'O Preço de um Resgate',
#  'Campo do Medo',
#  'Garota Exemplar',
#  'Truque de Mestre',
#  'Fratura',
#  'O Intruso',
#  'Um Contratempo',
#  'Encontro Fatal',
#  'Obsessão Secreta',
#  'Paixão Obsessiva',
#  'O Guardião Invisível',
#  'Mentiras Perigosas',
#  'O Protetor',
#  'Amnésia',
#  'Colateral',
#  'Sombra Lunar',
#  'A Justiceira',
#  'Fica Comigo',
#  'Ilha Do Medo',
#  'A Terra e o Sangue',
#  '22 de Julho',
#  'O Hóspede',
#  'Além da Realidade',
#  'A Marca do Demônio',
#  'Missão no Mar Vermelho',
#  'Alerta Lobo',
#  'Jogo Perigoso',
#  'A Qualquer Preço',
#  'A invasão',
#  'Além da Morte',
#  'Linha de Ação',
#  'Instinto Selvagem',
#  'Cascavel',
#  'Operação Final',
#  'Quando um Estranho Chama',
#  'El Camino: A Breaking Bad Film',
#  'O Fascínio',
#  'Psicose',
#  'A Cura',
#  'Seven - Os sete crimes capitais',
#  'O Dossiê Pelicano',
#  'The Titan',
#  'Sob o domínio do mal',
#  'O Caderno de Sara',
#  'Joias Brutas',
#  'Circle',
#  'Durante a Tormenta',
#  'Um Dia Difícil',
#  'Desaparecida',
#  'Sem Perdão',
#  'King: Uma História de Vingança',
#  'Amores Canibais',
#  'Tempo de Caça',
#  'O mistério das garotas perdidas',
#  'Cópias - De Volta à Vida',
#  'Quatro Histórias de Fantasmas',
#  'O Impostor',
#  '1922',
#  'Ecos do Além',
#  'I Am Mother',
#  'Rede de Ódio',
#  'Mom',
#  'Gravidade',
#  'Boneco de Neve',
#  'O Homem das Mil Caras',
#  'A Casa',
#  'Mate-me mais uma vez',
#  'Bita e os Animais',
#  'Nanny McPhee - A babá encantada',
#  'Scooby-Doo 2: Monstros à Solta',
#  'Meu Malvado Favorito 2',
#  'A Menina e o Leão',
#  'Tá Chovendo Hambúrguer',
#  "Bob Esponja - Um Herói Fora D'Água",
#  'Emoji: O Filme',
#  'A Fantástica Fábrica de Chocolate',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Alvin e os Esquilos: Na Estrada',
#  'Feel the Beat',
#  'Matilda',
#  'Pets Unidos!',
#  'As férias de Mr. Bean',
#  'A noiva-cadáver',
#  'Mogli - Entre Dois Mundos',
#  'Tá Chovendo Hambúrguer 2',
#  'O Natal de Cinderela',
#  'O Grinch',
#  'Crush à Altura',
#  'Luccas Neto em: Acampamento de Férias 2',
#  'Luccas Neto em: O Hotel Mágico',
#  'O Menino que Descobriu o Vento',
#  'O Segredo dos Animais',
#  'Luccas Neto em: Uma Babá Muito Esquisita',
#  'O Príncipe do Natal',
#  'Meu Malvado Favorito',
#  'O Chefinho – Pega Esse Bebê!',
#  'A Bailarina',
#  'Hotel Transilvânia',
#  'Os Smurfs 2',
#  'Shrek para Sempre – O Capítulo Final',
#  'Klaus',
#  'Madagascar 3: Os procurados',
#  'Luccas Neto em: Acampamento de Férias',
#  'Carrossel, O Filme',
#  'Manual de Caça a Monstros',
#  'Viagem ao Centro da Terra',
#  'Barbie e os Golfinhos Mágicos',
#  'O Expresso Polar',
#  'Madagascar 2',
#  'O Príncipe do Natal: O Bebê Real',
#  'Luccas Neto em: Dia das Crianças',
#  'Rango',
#  'Um Passado de Presente',
#  'O Príncipe do Natal: O Casamento Real',
#  'A Origem dos Guardiões',
#  'Milagres do Paraíso',
#  'A Menina e o Porquinho',
#  'Os Smurfs e a Vila Perdida',
#  'Pokémon: Mewtwo Contra-ataca — Evolução',
#  'Madagascar',
#  'Os Irmãos Willoughby',
#  'Luccas Neto em: O Fim do Natal',
#  'Kung Fu Panda',
#  'Os Sem-Floresta',
#  'Como treinar o seu dragão',
#  'Resgate do Coração',
#  'O Último Mestre do Ar',
#  'Bee Movie - A história de uma abelha',
#  'Shrek Terceiro',
#  'Operação Presente',
#  'Goosebumps: Monstros e Arrepios',
#  'A Viagem de Chihiro',
#  'Carrossel 2 – O Sumiço de Maria Joaquina',
#  'O Pequeno Príncipe',
#  'Animais Fantásticos e Onde Habitam',
#  'Space Jam - O Jogo do Século',
#  'O Castelo Animado',
#  'Mundo Bita - Bita e o Nosso Mundo',
#  'Mundo Bita - Bita e as Brincadeiras',
#  'O Natal Está no Ar',
#  'Cinderela Pop',
#  'Megamente',
#  'Era uma vez no Oeste',
#  'O cavaleiro das trevas',
#  'O Procurado',
#  'Parker',
#  'A Casa Caiu: Um Cassino na Vizinhança',
#  'S.W.A.T. – Comando Especial',
#  'Velozes & Furiosos 6',
#  'O Cobrador de Dívidas 2',
#  'Velozes e Furiosos',
#  'Vingança',
#  'Bala Perdida',
#  'Atirador',
#  'Velozes e Furiosos 3 – Desafio em Tóquio',
#  'Operação Fronteira',
#  'Colombiana - em busca de vingança',
#  'O Diabo de Cada Dia',
#  'O Máskara',
#  'S.W.A.T. - Operação Escorpião',
#  'Em Ritmo de Fuga',
#  'Cenas de um Homicídio: Uma Família Vizinha',
#  'Fique rico ou morra tentando',
#  'O Protetor',
#  'Polar',
#  'A Hora do Rush 2',
#  'Um olhar do paraíso',
#  '+ Velozes + Furiosos',
#  'Operações Especiais',
#  'Vingança Fatal',
#  'Shaft',
#  'À Espera de um milagre',
#  'Família do Bagulho',
#  'Velozes e Furiosos 4',
#  'Uma saída de mestre',
#  'Os donos da rua',
#  'Bright',
#  'Remédio Amargo',
#  'Golpe Duplo',
#  'Dose Dupla',
#  'Django Livre',
#  'O Preço de um Resgate',
#  'O Cobrador de Dívidas',
#  'Estrada Sem Lei',
#  'Lucy',
#  'O Agente da U.N.C.L.E.',
#  'O Irlandês',
#  'Aliança do Crime',
#  'Por Uma Vida Melhor',
#  'O Gângster',
#  'Garota Exemplar',
#  'Batman Begins',
#  'Bad Boys 2',
#  'Truque de Mestre',
#  'Tiro e queda',
#  'O Intruso',
#  'O Grande Mestre 3',
#  'Um Contratempo',
#  'Um Tira da Pesada',
#  'The Last Days of American Crime',
#  'O Guardião Invisível',
#  'O Durão',
#  'O Contador',
#  'Segurança de shopping',
#  'O Protetor',
#  'Vingança sem Limites',
#  'Carga Bruta',
#  'Desejo de Matar',
#  'Blade Runner 2049',
#  'Colateral',
#  'No Corredor da Morte',
#  'Kick-Ass – Quebrando tudo',
#  'Missão Pijamas',
#  'Sombra Lunar',
#  'Risco Máximo',
#  'Batman - O Cavaleiro das Trevas Ressurge',
#  'Jack Reacher - O Último Tiro',
#  'Emoji: O Filme',
#  'A Fantástica Fábrica de Chocolate',
#  'Viagem 2 - A Ilha Misteriosa',
#  'Feel the Beat',
#  'Matilda',
#  'Pets Unidos!',
#  'As férias de Mr. Bean',
#  'A noiva-cadáver',
#  'Tá Chovendo Hambúrguer 2',
#  'O Natal de Cinderela',
#  'O Grinch',
#  'Crush à Altura',
#  'Luccas Neto em: Acampamento de Férias 2',
#  'Luccas Neto em: O Hotel Mágico',
#  'O Segredo dos Animais',
#  'Luccas Neto em: Uma Babá Muito Esquisita',
#  'O Príncipe do Natal',
#  'Meu Malvado Favorito',
#  'O Chefinho – Pega Esse Bebê!',
#  'A Bailarina',
#  'Hotel Transilvânia',
#  'Os Smurfs 2',
#  'Shrek para Sempre – O Capítulo Final',
#  'Klaus',
#  'Madagascar 3: Os procurados',
#  'Luccas Neto em: Acampamento de Férias',
#  'Carrossel, O Filme',
#  'Manual de Caça a Monstros',
#  'Viagem ao Centro da Terra',
#  'Barbie e os Golfinhos Mágicos',
#  'O Feitiço do Natal',
#  'O Expresso Polar',
#  'Madagascar 2',
#  'O Príncipe do Natal: O Bebê Real',
#  'Luccas Neto em: Dia das Crianças',
#  'Rango',
#  'Um Passado de Presente',
#  'O Príncipe do Natal: O Casamento Real',
#  'Cartão de Natal',
#  'A Origem dos Guardiões',
#  'Meus 15 Anos',
#  'A Menina e o Porquinho',
#  'Os Smurfs e a Vila Perdida',
#  'Pokémon: Mewtwo Contra-ataca — Evolução',
#  'Madagascar',
#  'Os Irmãos Willoughby',
#  'Luccas Neto em: O Fim do Natal',
#  'Kung Fu Panda',
#  'Os Sem-Floresta',
#  'Como treinar o seu dragão',
#  'O Último Mestre do Ar',
#  'Bee Movie - A história de uma abelha',
#  'Shrek Terceiro',
#  'Operação Presente',
#  'Goosebumps: Monstros e Arrepios',
#  'A Viagem de Chihiro',
#  'Carrossel 2 – O Sumiço de Maria Joaquina',
#  'O Pequeno Príncipe',
#  'Space Jam - O Jogo do Século',
#  'O Castelo Animado',
#  'O Natal Está no Ar',
#  'Cinderela Pop',
#  'Megamente',
#  'Olhos de Gato',
#  'Kung Fu Panda 2',
#  'Hop - Rebelde sem Páscoa',
#  'Ponyo - Uma Amizade que Veio do Mar',
#  'O Que Será de Nozes 2',
#  'Angry Birds: O Filme',
#  'Lego Ninjago: O Filme',
#  'É o Bicho!',
#  '3 Ninjas Contra Atacam',
#  'Bebês geniais',
#  'Astro Boy',
#  'Gato de Botas',
#  'Quarto de Guerra',
#  'Rocky: Um Lutador',
#  'Mulher-Maravilha',
#  'Um Natal de Descobertas',
#  'O Dilema das Redes',
#  'Rosa e Momo',
#  '#Alive',
#  'Alvin e os Esquilos: Na Estrada',
#  'Feel the Beat',
#  'Norbit',
#  'Matilda',
#  'Pets Unidos!',
#  'Roman J. Israel',
#  'O Procurado',
#  'BLACKPINK: Light Up the Sky',
#  'As férias de Mr. Bean',
#  'Mistério no Mediterrâneo',
#  'Parker',
#  'Por Lugares Incríveis',
#  'A noiva-cadáver',
#  'À prova de fogo',
#  'Hitch – Conselheiro Amoroso',
#  'Mogli - Entre Dois Mundos',
#  'A Casa Caiu: Um Cassino na Vizinhança',
#  'Tá Chovendo Hambúrguer 2',
#  ...]

# %%
pd.DataFrame(movie, columns = ['Movies'])
# Out:
#                                       Movies
# 0     The SpongeBob Movie: Sponge on the Run
# 1          Luccas Neto em: O Mapa do Tesouro
# 2                                   Holidate
# 3                   Operation Christmas Drop
# 4                        The Kissing Booth 2
# ...                                      ...
# 1270                           Puss in Boots
# 1271                               Astro Boy
# 1272                              Dad Wanted
# 1273                      Back to the Future
# 1274                      The Little Rascals
#
# [1275 rows x 1 columns]
